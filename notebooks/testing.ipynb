# %% [markdown]
# # TESTING

# %%
import nflreadpy as nfl
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)            # no wrapping
pd.set_option("display.max_colwidth", None)  # show full text in cells

player_ids = nfl.load_ff_playerids()
player_ids_df = player_ids.to_pandas()

player_ids_df.sample(10)

# %%
import nflreadpy as nfl
players = nfl.load_players()
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)            # no wrapping
pd.set_option("display.max_colwidth", None)  # show full text in cells
p_df = players.to_pandas()

# p_df.info()
print(p_df.loc[p_df["display_name"].eq("Devonta Freeman")])
# p_df.sample(5)

# %%
import nflreadpy as nfl
YEARS: list[int] = list(range(2012, 2025))
schedules = nfl.load_schedules(seasons=YEARS)

schedules_df = schedules.to_pandas()
schedules_df.columns.tolist()

# schedules_df.info()
# schedules_df.sample(1)
# Out:
# ['game_id',
#  'season',
#  'game_type',
#  'week',
#  'gameday',
#  'weekday',
#  'gametime',
#  'away_team',
#  'away_score',
#  'home_team',
#  'home_score',
#  'location',
#  'result',
#  'total',
#  'overtime',
#  'old_game_id',
#  'gsis',
#  'nfl_detail_id',
#  'pfr',
#  'pff',
#  'espn',
#  'ftn',
#  'away_rest',
#  'home_rest',
#  'away_moneyline',
#  'home_moneyline',
#  'spread_line',
#  'away_spread_odds',
#  'home_spread_odds',
#  'total_line',
#  'under_odds',
#  'over_odds',
#  'div_game',
#  'roof',
#  'surface',
#  'temp',
#  'wind',
#  'away_qb_id',
#  'home_qb_id',
#  'away_qb_name',
#  'home_qb_name',
#  'away_coach',
#  'home_coach',
#  'referee',
#  'stadium_id',
#  'stadium']

# %%
import nflreadpy as nfl
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)            # no wrapping
pd.set_option("display.max_colwidth", None)  # show full text in cells

YEARS: list[int] = list[int](range(2012, 2025))
player_stats = nfl.load_player_stats(seasons=YEARS)

player_stats_df = player_stats.to_pandas()

player_stats_df.columns.tolist()
# player_stats_df.info()
# player_stats_df.sample(10)
# print(player_stats_df.loc[player_stats_df["player_display_name"].eq("Devonta Freeman")])
# Out:
# ['player_id',
#  'player_name',
#  'player_display_name',
#  'position',
#  'position_group',
#  'headshot_url',
#  'season',
#  'week',
#  'season_type',
#  'team',
#  'opponent_team',
#  'completions',
#  'attempts',
#  'passing_yards',
#  'passing_tds',
#  'passing_interceptions',
#  'sacks_suffered',
#  'sack_yards_lost',
#  'sack_fumbles',
#  'sack_fumbles_lost',
#  'passing_air_yards',
#  'passing_yards_after_catch',
#  'passing_first_downs',
#  'passing_epa',
#  'passing_cpoe',
#  'passing_2pt_conversions',
#  'pacr',
#  'carries',
#  'rushing_yards',
#  'rushing_tds',
#  'rushing_fumbles',
#  'rushing_fumbles_lost',
#  'rushing_first_downs',
#  'rushing_epa',
#  'rushing_2pt_conversions',
#  'receptions',
#  'targets',
#  'receiving_yards',
#  'receiving_tds',
#  'receiving_fumbles',
#  'receiving_fumbles_lost',
#  'receiving_air_yards',
#  'receiving_yards_after_catch',
#  'receiving_first_downs',
#  'receiving_epa',
#  'receiving_2pt_conversions',
#  'racr',
# ...
