# %% [markdown]
# # TESTING

# %%
import nflreadpy as nfl
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)            # no wrapping
pd.set_option("display.max_colwidth", None)  # show full text in cells

player_ids = nfl.load_ff_playerids()
player_ids_df = player_ids.to_pandas()

player_ids_df.sample(10)

# %%
import nflreadpy as nfl
players = nfl.load_players()
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)            # no wrapping
pd.set_option("display.max_colwidth", None)  # show full text in cells
p_df = players.to_pandas()

p_df.info()
# print(p_df.loc[p_df["display_name"].eq("Devonta Freeman")])
p_df.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24327 entries, 0 to 24326
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   gsis_id                       24327 non-null  object
#  1   display_name                  24327 non-null  object
#  2   common_first_name             24327 non-null  object
#  3   first_name                    24327 non-null  object
#  4   last_name                     24327 non-null  object
#  5   short_name                    7312 non-null   object
#  6   football_name                 7794 non-null   object
#  7   suffix                        164 non-null    object
#  8   esb_id                        24327 non-null  object
#  9   nfl_id                        11402 non-null  object
#  10  pfr_id                        22158 non-null  object
#  11  pff_id                        11208 non-null  object
#  12  otc_id                        9316 non-null   object
#  13  espn_id                       16065 non-null  object
#  14  smart_id                      24327 non-null  object
#  15  birth_date                    24296 non-null  object
#  16  position_group                24327 non-null  object
#  17  position                      24327 non-null  object
#  18  ngs_position_group            4971 non-null   object
#  19  ngs_position                  4883 non-null   object
#  20  height                        24317 non-null  float64
#  21  weight                        24316 non-null  float64
#  22  headshot                      24178 non-null  object
#  23  college_name                  24327 non-null  object
#  24  college_conference            6145 non-null   object
#  25  jersey_number                 23444 non-null  object
#  26  rookie_season                 24327 non-null  int32
#  27  last_season                   24327 non-null  int32
#  28  latest_team                   24327 non-null  object
#  29  status                        24327 non-null  object
#  30  ngs_status                    7795 non-null   object
#  31  ngs_status_short_description  6173 non-null   object
#  32  years_of_experience           24327 non-null  int32
#  33  pff_position                  7342 non-null   object
#  34  pff_status                    3774 non-null   object
#  35  draft_year                    12129 non-null  float64
#  36  draft_round                   12129 non-null  float64
#  37  draft_pick                    12129 non-null  float64
#  38  draft_team                    12129 non-null  object
# dtypes: float64(5), int32(3), object(31)
# memory usage: 7.0+ MB
#           gsis_id         display_name common_first_name first_name  \
# 18317  00-0025462     Laurent Robinson           Laurent    Laurent
# 14070  00-0033280  Christian McCaffrey         Christian  Christian
# 17966  00-0027388           Aaron Rhea             Aaron      Aaron
# 8435   00-0027398            Trent Guy             Trent      Trent
# 22464  00-0021931         Kevin Walter             Kevin      Kevin
#
#        last_name   short_name football_name suffix     esb_id nfl_id  \
# 18317   Robinson         None          None   None  ROB609376  32268
# 14070  McCaffrey  C.McCaffrey     Christian   None  MCC035988  44820
# 17966       Rhea         None          None   None  RHE194895   None
# 8435         Guy         None          None   None  GUY451769   None
# 22464     Walter         None          None   None  WAL652190  28290
#
#          pfr_id pff_id otc_id  espn_id                              smart_id  \
# 18317  RobiLa01   3691   3833    10519  3200524f-4260-9376-4bbe-e9e8ad1c3189
# 14070  McCaCh01  11763   5592  3117251  32004d43-4303-5988-790d-0077d6a4692b
# 17966      None   None   None     None  32005248-4519-4895-fba9-8727e1912b10
# 8435   GuyxTr00   None   None     None  32004755-5945-1769-76f2-d5c5c208b9b6
# 22464  WaltKe00   1549   2104     4713  32005741-4c65-2190-6fec-0b648da48c08
#
#        birth_date position_group position ngs_position_group ngs_position  \
# 18317  1985-05-20             WR       WR               None         None
# 14070  1996-06-07             RB       RB                 RB           RB
# 17966        None             WR       WR               None         None
# 8435   1987-08-22             WR       WR               None         None
# 22464  1981-08-04             WR       WR               None         None
#
#        height  weight  \
# 18317    74.0   205.0
# 14070    71.0   210.0
# 17966    73.0   202.0
# 8435     68.0   171.0
# 22464    75.0   218.0
#
#                                                                                  headshot  \
# 18317  https://static.www.nfl.com/image/private/f_auto,q_auto/league/nqnfkywjavrt1bukmhap
# 14070   https://static.www.nfl.com/image/upload/f_auto,q_auto/league/resjdwihunsqckohcorj
# 17966  https://static.www.nfl.com/image/private/f_auto,q_auto/league/bqt06tsddv4pmbv7z64r
# 8435   https://static.www.nfl.com/image/private/f_auto,q_auto/league/iamsrassmaerks1vfsus
# 22464  https://static.www.nfl.com/image/private/f_auto,q_auto/league/yc4wxbkvjqddtgi2fisq
#
#                   college_name         college_conference jersey_number  \
# 18317           Illinois State                       None            81
# 14070                 Stanford  Pacific Twelve Conference            23
# 17966  Stephen F. Austin State                       None             0
# 8435                Louisville                       None            84
# 22464         Eastern Michigan                       None            87
#
#        rookie_season  last_season latest_team status ngs_status  \
# 18317           2007         2012         JAX    RES       None
# 14070           2017         2025          SF    ACT        ACT
# 17966           2009         2009         MIN    RES       None
# 8435            2010         2010         CAR    DEV       None
# 22464           2003         2013         TEN    PUP       None
#
#       ngs_status_short_description  years_of_experience pff_position  \
# 18317                         None                    6           WR
# 14070                       Active                    9           HB
# 17966                         None                    0         None
# 8435                          None                    0         None
# 22464                         None                   11           WR
#
#       pff_status  draft_year  draft_round  draft_pick draft_team
# 18317       None      2007.0          3.0        75.0        ATL
# 14070          A      2017.0          1.0         8.0        CAR
# 17966       None         NaN          NaN         NaN       None
# 8435        None         NaN          NaN         NaN       None
# 22464       None      2003.0          7.0       255.0        NYG

# %%
import nflreadpy as nfl
YEARS: list[int] = list(range(2012, 2025))
schedules = nfl.load_schedules(seasons=YEARS)

schedules_df = schedules.to_pandas()
schedules_df.columns.tolist()

# schedules_df.info()
# schedules_df.sample(1)
# Out:
# ['game_id',
#  'season',
#  'game_type',
#  'week',
#  'gameday',
#  'weekday',
#  'gametime',
#  'away_team',
#  'away_score',
#  'home_team',
#  'home_score',
#  'location',
#  'result',
#  'total',
#  'overtime',
#  'old_game_id',
#  'gsis',
#  'nfl_detail_id',
#  'pfr',
#  'pff',
#  'espn',
#  'ftn',
#  'away_rest',
#  'home_rest',
#  'away_moneyline',
#  'home_moneyline',
#  'spread_line',
#  'away_spread_odds',
#  'home_spread_odds',
#  'total_line',
#  'under_odds',
#  'over_odds',
#  'div_game',
#  'roof',
#  'surface',
#  'temp',
#  'wind',
#  'away_qb_id',
#  'home_qb_id',
#  'away_qb_name',
#  'home_qb_name',
#  'away_coach',
#  'home_coach',
#  'referee',
#  'stadium_id',
#  'stadium']

# %%
import nflreadpy as nfl
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)            # no wrapping
pd.set_option("display.max_colwidth", None)  # show full text in cells

YEARS: list[int] = list[int](range(2012, 2025))
player_stats = nfl.load_player_stats(seasons=YEARS)

player_stats_df = player_stats.to_pandas()

player_stats_df.columns.tolist()
# player_stats_df.info()
# player_stats_df.sample(10)
# print(player_stats_df.loc[player_stats_df["player_display_name"].eq("Devonta Freeman")])
# Out:
# ['player_id',
#  'player_name',
#  'player_display_name',
#  'position',
#  'position_group',
#  'headshot_url',
#  'season',
#  'week',
#  'season_type',
#  'team',
#  'opponent_team',
#  'completions',
#  'attempts',
#  'passing_yards',
#  'passing_tds',
#  'passing_interceptions',
#  'sacks_suffered',
#  'sack_yards_lost',
#  'sack_fumbles',
#  'sack_fumbles_lost',
#  'passing_air_yards',
#  'passing_yards_after_catch',
#  'passing_first_downs',
#  'passing_epa',
#  'passing_cpoe',
#  'passing_2pt_conversions',
#  'pacr',
#  'carries',
#  'rushing_yards',
#  'rushing_tds',
#  'rushing_fumbles',
#  'rushing_fumbles_lost',
#  'rushing_first_downs',
#  'rushing_epa',
#  'rushing_2pt_conversions',
#  'receptions',
#  'targets',
#  'receiving_yards',
#  'receiving_tds',
#  'receiving_fumbles',
#  'receiving_fumbles_lost',
#  'receiving_air_yards',
#  'receiving_yards_after_catch',
#  'receiving_first_downs',
#  'receiving_epa',
#  'receiving_2pt_conversions',
#  'racr',
#  'target_share',
#  'air_yards_share',
#  'wopr',
#  'special_teams_tds',
#  'def_tackles_solo',
#  'def_tackles_with_assist',
#  'def_tackle_assists',
#  'def_tackles_for_loss',
#  'def_tackles_for_loss_yards',
#  'def_fumbles_forced',
#  'def_sacks',
#  'def_sack_yards',
#  'def_qb_hits',
#  'def_interceptions',
#  'def_interception_yards',
#  'def_pass_defended',
#  'def_tds',
#  'def_fumbles',
#  'def_safeties',
#  'misc_yards',
#  'fumble_recovery_own',
#  'fumble_recovery_yards_own',
#  'fumble_recovery_opp',
#  'fumble_recovery_yards_opp',
#  'fumble_recovery_tds',
#  'penalties',
#  'penalty_yards',
#  'punt_returns',
#  'punt_return_yards',
#  'kickoff_returns',
#  'kickoff_return_yards',
#  'fg_made',
#  'fg_att',
#  'fg_missed',
#  'fg_blocked',
#  'fg_long',
#  'fg_pct',
#  'fg_made_0_19',
#  'fg_made_20_29',
#  'fg_made_30_39',
#  'fg_made_40_49',
#  'fg_made_50_59',
#  'fg_made_60_',
#  'fg_missed_0_19',
#  'fg_missed_20_29',
#  'fg_missed_30_39',
#  'fg_missed_40_49',
#  'fg_missed_50_59',
#  'fg_missed_60_',
#  'fg_made_list',
#  'fg_missed_list',
#  'fg_blocked_list',
#  'fg_made_distance',
#  'fg_missed_distance',
#  'fg_blocked_distance',
#  'pat_made',
#  'pat_att',
#  'pat_missed',
#  'pat_blocked',
#  'pat_pct',
#  'gwfg_made',
#  'gwfg_att',
#  'gwfg_missed',
#  'gwfg_blocked',
#  'gwfg_distance',
#  'fantasy_points',
#  'fantasy_points_ppr']
